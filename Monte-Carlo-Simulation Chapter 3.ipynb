# %% [markdown]
# ## 3.5.2 Construct a Monte-Carlo simulation program to calculate the area under the curve of the function y = sqrt(x) / (1 + 0.1*sinπx) between the limits x = 0 and x = 1 (the area is 0.626, correct to three significant figures).

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

import random

# Plotting the curve

# xdata = np.linspace(0,1,200)
# xdata.sort() 
# ydata = np.sqrt(xdata)/(1 + 0.1 * np.sin(np.pi) * xdata)

# plt.plot(xdata, ydata, 'b')
# plt.show()


r = 1
h = 1

hits = np.full(n,0)

for i in range(50):
  print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-06638ffb9546> in <module>
#      20 hits = np.full(n,0)
#      21
# ---> 22 for i in range(50):
#      23   print(i)
#      24
#
# TypeError: 'int' object is not callable
